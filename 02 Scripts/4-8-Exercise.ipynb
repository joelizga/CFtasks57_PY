# %% [markdown]
# 4-8 Exercise

# %% [markdown]
# 01 Import Libraries and Dataset

# %%
#01.1 import libraries
import pandas as pd
import numpy as np
import os

# %%
#01.2 Make pathe to dataframe file
path=r'D:\Joan\CareerFoundry\Assessment 4\2024-08-Instacart Basket Analysis\02 Data\Prepared Data'

# %%
#01.3 import dataframe ords_prods_merge_47.pkl as ords_prods_merge
df_ords_prods_merge=pd.read_pickle(os.path.join(path, 'ords_prods_merge_47.pkl'))

# %%
#01.4 create subset of first million rows in df_ords_prods_merge
df = df_ords_prods_merge[:1000000]

# %%
#01.5 check shape
df.shape
# Out:
# (1000000, 19)

# %%
#01.6 check columns
df.head
# Out:
# <bound method NDFrame.head of         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2539329        1             1                   2
# 2        2539329        1             1                   2
# 3        2539329        1             1                   2
# 4        2539329        1             1                   2
# ...          ...      ...           ...                 ...
# 999995   3264026     6467            54                   6
# 999996   2845775     6467            55                   3
# 999997   2845775     6467            55                   3
# 999998   2845775     6467            55                   3
# 999999   2845775     6467            55                   3
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                       8                     NaN         196
# 1                       8                     NaN       14084
# ...

# %%
#01.7 check columns df
df.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'buiest_period_of_day', 'busiest_period_of_day'],
#       dtype='object')

# %%
#01.8 delete buiest_period_of_day and _merge columns
df=df.drop(columns=['buiest_period_of_day'])

# %%
df=df.drop(columns=['_merge'])

# %%
#01.9 check df shape after deletions
df.shape
# Out:
# (1000000, 17)

# %% [markdown]
# 02 Grouping Data

# %%
#02.1 Group df by product name column
df.groupby('product_name')

# %% [markdown]
# 03 Aggregating Data

# %%
#03.1 Group df by department id and then find mean of order_number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.792915
# 2.0              17.091743
# 3.0              17.919589
# 4.0              17.891973
# 5.0              15.214270
# 6.0              15.382228
# 7.0              17.699986
# 8.0              16.485269
# 9.0              15.965921
# 10.0             20.091818
# 11.0             16.485395
# 12.0             15.615845
# 13.0             16.485052
# 14.0             17.523474
# 15.0             15.690354
# 16.0             18.014342
# 17.0             16.155822
# 18.0             19.606536
# 19.0             17.630236
# 20.0             17.138204
# 21.0             21.996844

# %%
#03.2 different method to find mean
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.792915
# 2.0     17.091743
# 3.0     17.919589
# 4.0     17.891973
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    15.615845
# 13.0    16.485052
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.014342
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630236
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %%
#03.3 performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.792915   1  99
# 2.0              17.091743   1  98
# 3.0              17.919589   1  99
# 4.0              17.891973   1  99
# 5.0              15.214270   1  99
# 6.0              15.382228   1  99
# 7.0              17.699986   1  99
# 8.0              16.485269   1  91
# 9.0              15.965921   1  99
# 10.0             20.091818   1  99
# 11.0             16.485395   1  99
# 12.0             15.615845   1  99
# 13.0             16.485052   1  99
# 14.0             17.523474   1  99
# 15.0             15.690354   1  99
# 16.0             18.014342   1  99
# 17.0             16.155822   1  99
# 18.0             19.606536   1  99
# 19.0             17.630236   1  99
# 20.0             17.138204   1  99
# 21.0             21.996844   1  97

# %%
#delete columns in main dataframe
df_ords_prods_merge=df_ords_prods_merge.drop(cbolumns=['buiest_period_of_day', '_merge'])

# %%
df_ords_prods_merge.shape
# Out:
# (32435059, 17)

# %% [markdown]
# 04 Aggregating Data with Transform

# %%
#04.1 create max order column
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\jonba\AppData\Local\Temp\ipykernel_13612\2829912185.py:2: FutureWarning: The provided callable <function max at 0x000001C8A09F65C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#04.2 see first five fows of df_ords_prods_merge
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
#04.3 turn off max row restriction
pd.options.display.max_rows = None

# %%
#04.4 see first 100 rows
df_ords_prods_merge.head(100)

# %%
#04.5 Create loyalty flag values of Loyal customer, Regular customer, and New customer
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#04.6 show frequency of loyalty flags
df_ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: count, dtype: int64

# %%
#04.7 head function for limited number of columns
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, 'ords_prods_merge_47.pkl'))

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path, 'ords_prods_merge_47.pkl'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 ords_prods_merge=pd.read_pickle(os.path.join(path, 'ords_prods_merge_47.pkl'))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     199     with warnings.catch_warnings(record=True):
#     200         # We want to silence any warnings about, e.g. moved modules.
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#     207     return pc.load(handles.handle, encoding=None)
#
# MemoryError:

# %%
ords_prods_merge.shape
