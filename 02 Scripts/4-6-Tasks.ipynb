# %% [markdown]
# 4-6 End of Lesson Tasks

# %% [markdown]
# #01 Importing Libraries and Dataframes

# %%
#01.1 importing libraries
import pandas as pd
import numpy as np
import os

# %%
#01.2 create path to project files
path=r'D:\Joan\CareerFoundry\Assessment 4\2024-08-Instacart Basket Analysis'

# %%
#01.3 importing orders_products_combined dataframe as df_op_combined
df_op_combined=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#01.4 see shape of df_op_combined
df_op_combined.shape
# Out:
# (32434489, 11)

# %%
#01.5 importing df_products_checked as df_prods
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
#01.6 see shape of df_prods
df_prods.shape
# Out:
# (49672, 6)

# %% [markdown]
# #02 Combining Dataframes df_prods and df_op_combined

# %%
#02.1 see columns on df_prods
df_prods.columns
# Out:
# Index(['Unnamed: 0', 'product_id', 'product_name', 'aisle_id', 'department_id',
#        'prices'],
#       dtype='object')

# %%
#02.3 see columns on df_op_combined
df_op_combined.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'order_number',
#        'orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge'],
#       dtype='object')

# %%
#02.4 see first five rows of df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#02.5 see first five rows of df_op_combined
df_op_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
#02.6 I believe I can merge them on the product_id column. I want to keep everything from df_op_combined and bring in the data from df_prods if it has matching product_id in df_op_combined
#02.6 Sorry, I'm thinking this through. If I do the default of an inner merge, then if an order contains a product_id that is not in my products df, it will not be included in the merge. 
#02.6 I don't want to lose any orders. I am going to do a left join whith df_op_combined as A and df_prods as B.

# %%
#02.7 test left join of df_op_combined with df_prods
#02.7 pd.merge(df_op_combined, df_prods, on = 'product_id', how='left', indicator=True)
#02.7 when I tried to run the above I got an error because the _merge column already exists. I am going to delete it and the unnamed column and then move forward with the merge.

# %%
#02.8 delete columns Unnamed: 0 and _merge from df_op_combined
df_op_combined_2=df_op_combined.drop(columns=['Unnamed: 0', '_merge'])

# %%
#02.9 check columns in df_op_combined_2
df_op_combined_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
#02.10 test left join of df_op_combined_2 with df_prods
pd.merge(df_op_combined_2, df_prods, on = 'product_id', how='left', indicator=True)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32435054   2977660   206209            13                   1
# 32435055   2977660   206209            13                   1
# 32435056   2977660   206209            13                   1
# 32435057   2977660   206209            13                   1
# 32435058   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
#02.11 left join of df_op_combined_2 with df_prods
df_merged=df_op_combined_2.merge(df_prods, on = 'product_id', how='left', indicator=True)

# %%
#02.12 check merge column values in df_merged
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only        30200
# right_only           0
# Name: count, dtype: int64

# %%
#02.12 check shape of new df_merged
df_merged.shape
# Out:
# (32435059, 15)

# %%
#02.13 create subset of left only
df_merged_lo=df_merged.loc[df_merged['_merge'].isin(['left_only'])]

# %%
df_merged_lo.shape
# Out:
# (30200, 15)

# %%
df_merged_lo.head()
# Out:
#       order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 2963      7099       27            63                   3                 10
# 3205   1837192       27            80                   2                  8
# 3253   3331846       28             3                   0                 16
# 3395   1385910       28            21                   2                 17
# 4694   2873174       38             1                   0                 10
#
#       days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 2963                     1.0        6799                  1          0
# 3205                     6.0        6799                  9          1
# 3253                     2.0          34                  6          0
# 3395                     1.0          34                  1          1
# 4694                     NaN         116                 11          0
#
#       Unnamed: 0 product_name  aisle_id  department_id  prices     _merge
# ...

# %%
#02.14 There were 30,200 product_ids in the df_op_combined_2 that did not have matching product_ids in the df_prods.

# %% [markdown]
# #03 Finalize Dataframe and export

# %%
#03.1 delete the Unnamed: 0 column from df_merged
df_merged=df_merged.drop(columns=['Unnamed: 0'])

# %%
#03.2 check df_merged shape
df_merged.shape
# Out:
# (32435059, 14)

# %%
#03.3 export df_merged as ords_prods_merge.pkl without unnamed column :)
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
